# %% [markdown]
# <a href="https://colab.research.google.com/github/lianiindri/STUDIindependen/blob/main/indri_Latihan_dasar_visualisasi_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization with Matplotlib library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basic Visualization

# %%
height = [150,160,165,185]
weight = [70,80,90,100]
plt.plot(height,weight,color='red')

# %% [markdown]
# ## Judul dan label

# %%
plt.plot(height,weight)
# to give title to the graph/figure
plt.title('Height vs Weight graph')
# Add x label
plt.xlabel("height")
# Add y Label
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %% [markdown]
# ## Plotting lebih dari 1 garis

# %%
calories_burnt = [65,75,95,99]
#Plotting 2 lines
plt.plot(height, calories_burnt)
plt.plot(height, weight)

# to give title to the graph/figure
plt.title('Calorie vs Weight over the Height graph')

# Add x label
plt.xlabel("height")

# Add y Label
plt.ylabel("weight and calorie")
# Out:
# Text(0, 0.5, 'weight and calorie')

# %% [markdown]
# ## penambahan legend ke plot/graph/figure

# %%
#Plotting 2 lines
plt.plot(height, calories_burnt)
plt.plot(height, weight)

# to give title to the graph/figure
plt.title('Calorie vs Weight over the Height graph')

# Add x label
plt.xlabel("height")

# Add y Label
plt.ylabel("weight and calorie")

# Adding legend to the plot/graph/figure
plt.legend(labels=['Calories',"weight"],loc='lower right')

# %% [markdown]
# ## Figure size

# %%
# figure size in inches, should be at the beginning
plt.figure(figsize=(13,7))

#Plotting 2 lines
plt.plot(height, calories_burnt)
plt.plot(height, weight)

# to give title to the graph/figure
plt.title('Calorie vs Weight over the Height graph')

# Add x label
plt.xlabel("height")

# Add y Label
plt.ylabel("weight and calorie")

# Adding legend to the plot/graph/figure
plt.legend(labels=['Calories',"weight"],loc='lower right')

# %% [markdown]
# ## Mengganti bentuk garis

# %%
# figure size in inches, should be at the beginning
plt.figure(figsize=(13,5))

#Plotting 2 lines
plt.plot(height, calories_burnt, '--o')
plt.plot(height, weight,  'r-o')

# to give title to the graph/figure
plt.title('Calorie vs Weight over the Height graph')

# Add x label
plt.xlabel("height")

# Add y Label
plt.ylabel("weight and calorie")

# Adding legend to the plot/graph/figure
plt.legend(labels=['Calories',"weight"],loc='lower right')

# %% [markdown]
# ## Plotting data from dataframe
# ### Plotting by class
# Misalkan suatu perusahaan pesawat terbang ingin tahu perbedaan rata-rata usia penumpang tiap kelas

# %%
passenger_data = pd.read_csv('https://ngodingdata.com/wp-content/uploads/2020/05/titanic.csv')
passenger_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
passenger_data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#Menghitung rata-rata usia per kelas
age_by_pclass = passenger_data.groupby('Pclass')['Age'].mean()
age_by_pclass
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
x = age_by_pclass.index.tolist()      #x-axis is Passenger class (Pclass)
y = age_by_pclass.values.tolist()     #y-axis rata-rata usia

# %%
#Make a bar chart
plt.bar(x,y,color=['red','orange','pink'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Kita bisa menjelaskan ke perusahaan bahwa fasilitas kelas 1 lebih diminati penumpang berusia sekitar 36 tahun

# %% [markdown]
# # Latihan
# Kumpulkan hasilnya ke coach masing-masing
#
# 1. Coba tambahkan figure size, title of the figure, x-label, y-label, dan ubah warnanya.

# %%
#type your code here
#figure size
plt.figure(figsize=(10,6))
#Make a bar chart
plt.bar(x,y,color=['black','blue','yellow'])
#add title
plt.title('plot rata-rata umur penumpang berdasarkan kelas')
#add x-lab
plt.xlabel('passenger class')
#add y-lab
plt.ylabel('Age averge')
# Out:
# Text(0, 0.5, 'Age averge')

# %% [markdown]
# 2. Coba tambahkan figure size, x-label = passenger number, y-label= fare and age, dan legend pada chart berikut

# %%
#type your code here
plt.figure(figsize=(10,6))
passenger_data['Fare'].plot(kind='line')
passenger_data['Age'].plot(kind='line')

#add title
plt.title('Fare vs Age')
#add x-label
plt.xlabel('passenger number')
#add y-label
plt.ylabel('Fare and Age')
#add legend
plt.legend(labels=['Fare','Age'],loc='upper left',)

# %%
#type your code here
plt.figure(figsize=(10,6))
passenger_data['Fare'].plot(kind='line')
passenger_data['Age'].plot(kind='line')

#add title
plt.title('Fare vs Age')
#add x-label
plt.xlabel('passenger number')
#add y-label
plt.ylabel('Fare and Age')
#add legend
plt.legend(labels=['Fare','Age'],loc='upper left',)
